# %% [markdown]
# Este notebook simplemente contiene un script que genera un archivo csv para tener en cuenta el nombre del archivo y juntarlo con su respectiva clase.
#
# Para eso, se importa la carpeta en donde esta el dataset completo, y se lee cada nombre de archivo, se clasifica en su respectiva clase dependiend unicamente de la primera letra (por lo que suponemos que el dataset está correctamente etiquetado).
#
# https://www.programiz.com/python-programming/writing-csv-files

# %%
import os
import csv

# %%
f = r'/Users/joaquincubelli/Desktop/Smar(t)bin/DatasetReducido/'

# %%
with open('dataset.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    for name in os.listdir(f):
        if name[-3:]=='png':
            print(name, name[0])
            writer.writerow([name, name[0]])
# Out:
# L_419.png L
# L_425.png L
# L_343.png L
# T_957.png T
# L_357.png L
# T_943.png T
# L_431.png L
# B_248.png B
# L_37.png L
# T_770.png T
# T_764.png T
# B_274.png B
# B_26.png B
# T_994.png T
# L_380.png L
# B_506.png B
# B_32.png B
# T_980.png T
# L_394.png L
# T_758.png T
# B_260.png B
# B_937.png B
# L_169.png L
# B_923.png B
# L_141.png L
# L_627.png L
# L_633.png L
# T_599.png T
# L_155.png L
# T_572.png T
# T_22.png T
# L_800.png L
# T_214.png T
# L_814.png L
# T_200.png T
# B_738.png B
# T_566.png T
# T_36.png T
# B_710.png B
# L_182.png L
# L_828.png L
# L_196.png L
# B_704.png B
# B_843.png B
# B_857.png B
# L_753.png L
# L_747.png L
# T_406.png T
# B_658.png B
# B_880.png B
# T_360.png T
# L_974.png L
# T_374.png T
# L_960.png L
# B_894.png B
# T_1039.png T
# T_412.png T
# B_664.png B
# T_1011.png T
# L_790.png L
# L_948.png L
# B_102.png B
# B_116.png B
# T_348.png T
# T_1005.png T
# T_9.png T
# B_670.png B
# B_499.png B
# L_579.png L
# L_551.png L
# T_823.png T
# ...
